# %% [markdown]
# <a href="https://colab.research.google.com/github/Varunsaistark/reinforcment_learning/blob/main/Td3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch 
import torch.nn as nn
import gym
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from collections import namedtuple
import gym
import random
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
Experience = namedtuple('Experience',['state','next_state','action','reward','done'])

# %%
class replaybuffer():
  def __init__(self,capacity):
    self.memory = []
    self.capacity = capacity
    self.count = 0
  def push(self,x):
    if self.capacity>self.count:
      self.memory.append(x)
    else:
      self.memory[self.count%self.capacity] = x
    self.count+=1
  def sample(self,batch_size):
    e= random.sample(self.memory,batch_size)
    states = torch.tensor([e1.state for e1 in e]).to(device)
    actions = torch.tensor([e1.action for e1 in e]).to(device)
    next_states = torch.tensor([e1.next_state for e1 in e]).to(device)
    rewards = torch.tensor(([e1.reward for e1 in e])).to(device)
    dones = torch.tensor([e1.done for e1 in e]).to(device)

    return states.float(),actions.float(),next_states.float(),rewards,dones.int()
  def is_available(self,batch_size):
    return batch_size<=self.count

# %%
class Critic(nn.Module):
  def __init__(self,lr1,input_dims,fc1,fc2,num_actions,chkpt_dir = ''):
    super(Critic,self).__init__()
    self.input_dims = input_dims
    self.ck = chkpt_dir
    self.num_actions = num_actions
    self.fc1 = nn.Linear(self.input_dims+self.num_actions,fc1)
    self.fc2 = nn.Linear(fc1,fc2)
    self.fc3 = nn.Linear(fc2,1)
    self.optimiser = optim.Adam(self.parameters(),lr= lr1)
    self.to(device)
  def forward(self,state,action):
    out = self.fc1(torch.cat([state,action], dim=1))
    out = F.relu(out)
    out = self.fc2(out)
    out = F.relu(out)
    out = self.fc3(out)
    return out
  def save_checkpoints(self):
    print('saving checkpoints ....')
    torch.save(self.state_dict(),self.ck)
    print('checkpoint saved .. ')
  def load_ck(self):
    self.load_state_dict(torch.load(self.ck))
    print('ck loaded..')

# %%
class Actor(nn.Module):
  def __init__(self,fc1,lr2,fc2,ck_dir,num_actions,input_dims):
    super(Actor,self).__init__()
    self.i = input_dims
    self.dir = ck_dir
    self.num_actions = num_actions
    self.fc1 = nn.Linear(self.i,fc1)
    self.fc2 = nn.Linear(fc1,fc2)
    self.fc3 = nn.Linear(fc2,self.num_actions)
    self.optimiser = optim.Adam(self.parameters(),lr = lr2)
    self.to(device)
  def forward(self,state):
    out = self.fc1(state)
    out = F.relu(out)
    out = self.fc2(out)
    out = F.relu(out)
    out = torch.tanh(self.fc3(out))
    return out
  def save_checkpoints(self):
    print('saving checkpoints ....')
    torch.save(self.state_dict(),self.dir)
    print('checkpoint saved .. ')
  def load_ck(self):
    self.load_state_dict(torch.load(self.dir))
    print('ck loaded..')

# %%
class Agent():
  def __init__(self,lr1,lr2,input_dims,tau,env,
               gamma = 0.99,update_actor_interval =2,
               warmup = 1000,n_actions =1,max_size = 10000,
               fc1 =400,fc2 =300,batch_size = 64,noise =0.1):
    self.gamma = torch.tensor(gamma).to(device)
    self.tau =tau
    self.max_action = env.action_space.high
    self.min_action = env.action_space.low
    self.memory = replaybuffer(max_size)
    self.batch_size = batch_size
    self.learn_step = 0
    self.time_step = 0
    self.warmup = warmup
    self.num_actions = n_actions
    self.updateinterval = update_actor_interval
    self.file0 = '/content/drive/MyDrive/chrome_dino/lander_actortd3'
    self.file1 = '/content/drive/MyDrive/chrome_dino/lander_critic1td3'
    self.file2 = '/content/drive/MyDrive/chrome_dino/lander_critic2td3'
    self.file3 = '/content/drive/MyDrive/chrome_dino/targetlander_actortd3'
    self.file4 = '/content/drive/MyDrive/chrome_dino/targetlander_critic1td3'
    self.file5 = '/content/drive/MyDrive/chrome_dino/targetlander_critic2td3'
   
    
    self.actor = Actor(fc1,lr2,fc2,self.file0,self.num_actions,input_dims)
    self.critic1 = Critic(lr1,input_dims,fc1,fc2,self.num_actions,self.file1)
    self.critic2 = Critic(lr1,input_dims,fc1,fc2,self.num_actions,self.file2)
    self.targetactor = Actor(fc1,lr2,fc2,self.file3,self.num_actions,input_dims)
    self.targetcritic1 = Critic(lr1,input_dims,fc1,fc2,self.num_actions,self.file4)
    self.targetcritic2 = Critic(lr1,input_dims,fc1,fc2,self.num_actions,self.file5)
    self.noise  =noise

  def update_network_parameters(self,tau=1):
    for targetcritic1param,localparam in zip(self.targetcritic1.parameters(),self.critic1.parameters()):
      targetcritic1param.data.copy_(tau*localparam.data+(1-tau)*targetcritic1param.data)
    
    for targetcritic2param,localparam in zip(self.targetcritic2.parameters(),self.critic2.parameters()):
       targetcritic2param.data.copy_(tau*localparam.data+(1-tau)*targetcritic2param.data)
    
    for targetactorparam,localparam in zip(self.targetactor.parameters(),self.actor.parameters()):
      targetactorparam.data.copy_(tau*localparam.data+(1-tau)*targetactorparam.data)

  #update_network_parameters(1)
  
  def choose_action(self,observation):
    if self.time_step < self.warmup:
      action = torch.tensor(np.random.normal(scale=self.noise,
                                              size = (self.num_actions,)))
    else:
      state = torch.tensor(observation,dtype = torch.float).to(device)
      action = self.actor.forward(state).to(device)
    action_noise = action + torch.tensor(np.random.normal(scale =self.noise),
                                          dtype = torch.float).to(device)
    action_noise = torch.clamp(action_noise,self.min_action[0],self.max_action[0])
    self.time_step +=1

    return action_noise.cpu().detach().numpy()
    
  def store(self,e):
    self.memory.push(e)
  
  
    
  def learn(self):
    if self.memory.is_available(self.batch_size):
      state,action,next_state,reward,done = self.memory.sample(self.batch_size)
      target_action = self.targetactor.forward(next_state)
      target_action += torch.clamp(torch.tensor(np.random.normal(scale=0.2)),-0.5,0.5)
      target_action = torch.clamp(target_action,self.min_action[0],self.max_action[0])
    #see here error might come then convert done to int
      
      q1_ = self.targetcritic1.forward(next_state,target_action).view(64)
      q2_ = self.targetcritic2.forward(next_state,target_action).view(64)
      q1_ = q1_*(1-done)
      q2_ = q2_*(1-done)
      target_q = torch.min(q1_,q2_)
      q1 = self.critic1.forward(state,action)
      q2 = self.critic2.forward(state,action)
      q = torch.min(q1,q2)
      target = reward+self.gamma*target_q
      target = target.view(self.batch_size,1).float().detach()
      self.critic1.optimiser.zero_grad()
      self.critic2.optimiser.zero_grad()

      q1_loss = F.mse_loss(target,q1)
      q2_loss = F.mse_loss(target,q2)

      loss = q1_loss.float()+q2_loss.float()
      loss.backward()
      self.critic1.optimiser.step()
      self.critic2.optimiser.step()
      self.learn_step+=1

      if self.learn_step%self.updateinterval!=0:
        return 
      else:
        self.actor.optimiser.zero_grad()
        actor_loss = self.critic1(state,self.actor.forward(state))
        actor_loss = -torch.mean(actor_loss)
        actor_loss.backward()
        self.actor.optimiser.step()
      
        self.update_network_parameters(self.tau)
    else:
      return 

    

  def save_model(self):
    self.actor.save_checkpoints()
    self.targetactor.save_checkpoints()
    self.critic1.save_checkpoints()
    self.critic2.save_checkpoints()
    self.targetcritic1.save_checkpoints()
    self.targetcritic2.save_checkpoints()
    
  def load_model(self):
    self.actor.load_ck()
    self.targetactor.load_ck()
    self.critic1.load_ck()
    self.critic2.load_ck()
    self.targetcritic1.load_ck()
    self.targetcritic2.load_ck()

# %%
env = gym.make('Pendulum-v0')
agent = Agent(0.001,0.001,3,0.005,env)
agent.update_network_parameters()
num_episodes = 10000
rewards=[]
best_score =0
for i in range(num_episodes):
  observation = env.reset()
  done=False
  score= 0
  
  while not done:
    action = agent.choose_action(observation)
    next_state,reward,done,info = env.step(action)
    e1 = Experience(observation,next_state,action,reward,done)
    agent.store(e1)
    agent.learn()
    score+=reward 
    observation = next_state
  rewards.append(score)
  if i==0:
    best_score = score
  avg_score = np.mean(rewards[-100:])
  if best_score<score:
    best_score = score
    agent.save_model()
  print('Episode {} best score till now {} average score for the past 100ep {}'.format(i,best_score,avg_score))
# Out:
# Episode 0 best score till now -861.904121418747 average score for the past 100ep -861.904121418747
# Episode 1 best score till now -861.904121418747 average score for the past 100ep -1362.4873401005636
# Episode 2 best score till now -861.904121418747 average score for the past 100ep -1465.9846600906776
# Episode 3 best score till now -861.904121418747 average score for the past 100ep -1535.780397293922
# Episode 4 best score till now -861.904121418747 average score for the past 100ep -1511.3878514101477
# Episode 5 best score till now -861.904121418747 average score for the past 100ep -1502.9660485729858
# Episode 6 best score till now -861.904121418747 average score for the past 100ep -1529.2738829290777
# Episode 7 best score till now -861.904121418747 average score for the past 100ep -1534.6745484081534
# Episode 8 best score till now -861.904121418747 average score for the past 100ep -1541.4753472015325
# Episode 9 best score till now -861.904121418747 average score for the past 100ep -1560.520453825396
# Episode 10 best score till now -861.904121418747 average score for the past 100ep -1551.1839464668396
# Episode 11 best score till now -861.904121418747 average score for the past 100ep -1559.2590159624594
# Episode 12 best score till now -861.904121418747 average score for the past 100ep -1577.8700858174484
# Episode 13 best score till now -861.904121418747 average score for the past 100ep -1592.0495009437616
# Episode 14 best score till now -861.904121418747 average score for the past 100ep -1577.3690506949595
# Episode 15 best score till now -861.904121418747 average score for the past 100ep -1571.0567992801239
# Episode 16 best score till now -861.904121418747 average score for the past 100ep -1561.9959033409275
# Episode 17 best score till now -861.904121418747 average score for the past 100ep -1546.2460680049578
# Episode 18 best score till now -861.904121418747 average score for the past 100ep -1527.9486045993958
# Episode 19 best score till now -861.904121418747 average score for the past 100ep -1521.5867695873712
# Episode 20 best score till now -861.904121418747 average score for the past 100ep -1508.3720349167747
# Episode 21 best score till now -861.904121418747 average score for the past 100ep -1498.75517939499
# Episode 22 best score till now -861.904121418747 average score for the past 100ep -1480.251778308101
# Episode 23 best score till now -861.904121418747 average score for the past 100ep -1472.9547994069442
# Episode 24 best score till now -861.904121418747 average score for the past 100ep -1463.4603834015566
# Episode 25 best score till now -861.904121418747 average score for the past 100ep -1449.9389966992894
# Episode 26 best score till now -861.904121418747 average score for the past 100ep -1444.6746054923144
# Episode 27 best score till now -861.904121418747 average score for the past 100ep -1431.7520924760552
# Episode 28 best score till now -861.904121418747 average score for the past 100ep -1418.7542034031026
# Episode 29 best score till now -861.904121418747 average score for the past 100ep -1403.6768198177779
# Episode 30 best score till now -861.904121418747 average score for the past 100ep -1397.6213030229253
# Episode 31 best score till now -861.904121418747 average score for the past 100ep -1388.2660969746123
# Episode 32 best score till now -861.904121418747 average score for the past 100ep -1376.9078316907
# Episode 33 best score till now -861.904121418747 average score for the past 100ep -1365.1721007777073
# Episode 34 best score till now -861.904121418747 average score for the past 100ep -1350.964486348983
# Episode 35 best score till now -861.904121418747 average score for the past 100ep -1338.0026694862545
# Episode 36 best score till now -861.904121418747 average score for the past 100ep -1328.297040749419
# Episode 37 best score till now -861.904121418747 average score for the past 100ep -1322.4544106896192
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 38 best score till now -739.8463189157331 average score for the past 100ep -1307.5157416697762
# Episode 39 best score till now -739.8463189157331 average score for the past 100ep -1293.456271023427
# Episode 40 best score till now -739.8463189157331 average score for the past 100ep -1285.7257526885394
# Episode 41 best score till now -739.8463189157331 average score for the past 100ep -1273.3336381507888
# Episode 42 best score till now -739.8463189157331 average score for the past 100ep -1270.757664865137
# Episode 43 best score till now -739.8463189157331 average score for the past 100ep -1261.6681192443398
# Episode 44 best score till now -739.8463189157331 average score for the past 100ep -1252.4537065712773
# Episode 45 best score till now -739.8463189157331 average score for the past 100ep -1241.775394341982
# Episode 46 best score till now -739.8463189157331 average score for the past 100ep -1236.9849119812764
# Episode 47 best score till now -739.8463189157331 average score for the past 100ep -1230.686276871977
# Episode 48 best score till now -739.8463189157331 average score for the past 100ep -1223.2394470650631
# Episode 49 best score till now -739.8463189157331 average score for the past 100ep -1215.2810082218512
# Episode 50 best score till now -739.8463189157331 average score for the past 100ep -1211.7985985969422
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 51 best score till now -629.2442379857573 average score for the past 100ep -1200.5956301236502
# Episode 52 best score till now -629.2442379857573 average score for the past 100ep -1194.9959913858816
# Episode 53 best score till now -629.2442379857573 average score for the past 100ep -1193.6126626147245
# Episode 54 best score till now -629.2442379857573 average score for the past 100ep -1190.9172078398956
# Episode 55 best score till now -629.2442379857573 average score for the past 100ep -1187.6563187079907
# Episode 56 best score till now -629.2442379857573 average score for the past 100ep -1183.9954300902964
# Episode 57 best score till now -629.2442379857573 average score for the past 100ep -1182.3849322197802
# Episode 58 best score till now -629.2442379857573 average score for the past 100ep -1181.7112339494633
# Episode 59 best score till now -629.2442379857573 average score for the past 100ep -1176.7454876644401
# Episode 60 best score till now -629.2442379857573 average score for the past 100ep -1174.4301115297728
# Episode 61 best score till now -629.2442379857573 average score for the past 100ep -1173.7498956316665
# Episode 62 best score till now -629.2442379857573 average score for the past 100ep -1173.6850586280827
# Episode 63 best score till now -629.2442379857573 average score for the past 100ep -1173.5957757416963
# Episode 64 best score till now -629.2442379857573 average score for the past 100ep -1173.875167800383
# Episode 65 best score till now -629.2442379857573 average score for the past 100ep -1173.165638620736
# Episode 66 best score till now -629.2442379857573 average score for the past 100ep -1172.690362563366
# Episode 67 best score till now -629.2442379857573 average score for the past 100ep -1172.6468816163592
# Episode 68 best score till now -629.2442379857573 average score for the past 100ep -1172.2036835809427
# Episode 69 best score till now -629.2442379857573 average score for the past 100ep -1172.1824863509821
# Episode 70 best score till now -629.2442379857573 average score for the past 100ep -1171.5122317390906
# Episode 71 best score till now -629.2442379857573 average score for the past 100ep -1171.4609916200886
# Episode 72 best score till now -629.2442379857573 average score for the past 100ep -1171.913926212369
# Episode 73 best score till now -629.2442379857573 average score for the past 100ep -1170.973930310893
# Episode 74 best score till now -629.2442379857573 average score for the past 100ep -1170.8868404166544
# Episode 75 best score till now -629.2442379857573 average score for the past 100ep -1172.4319969571468
# Episode 76 best score till now -629.2442379857573 average score for the past 100ep -1171.778060555541
# Episode 77 best score till now -629.2442379857573 average score for the past 100ep -1171.239548296272
# Episode 78 best score till now -629.2442379857573 average score for the past 100ep -1171.140885563882
# Episode 79 best score till now -629.2442379857573 average score for the past 100ep -1170.3487866037635
# Episode 80 best score till now -629.2442379857573 average score for the past 100ep -1168.5574857926035
# Episode 81 best score till now -629.2442379857573 average score for the past 100ep -1168.025208625723
# Episode 82 best score till now -629.2442379857573 average score for the past 100ep -1166.1887686623916
# Episode 83 best score till now -629.2442379857573 average score for the past 100ep -1163.0100078761047
# Episode 84 best score till now -629.2442379857573 average score for the past 100ep -1160.9362511048753
# Episode 85 best score till now -629.2442379857573 average score for the past 100ep -1157.6513973846068
# Episode 86 best score till now -629.2442379857573 average score for the past 100ep -1154.1875195695748
# Episode 87 best score till now -629.2442379857573 average score for the past 100ep -1152.5203561804
# Episode 88 best score till now -629.2442379857573 average score for the past 100ep -1148.1383510701735
# Episode 89 best score till now -629.2442379857573 average score for the past 100ep -1145.1915978261575
# Episode 90 best score till now -629.2442379857573 average score for the past 100ep -1139.6412135346798
# Episode 91 best score till now -629.2442379857573 average score for the past 100ep -1137.1862761270843
# Episode 92 best score till now -629.2442379857573 average score for the past 100ep -1136.8612556010646
# Episode 93 best score till now -629.2442379857573 average score for the past 100ep -1134.8241342511706
# Episode 94 best score till now -629.2442379857573 average score for the past 100ep -1130.772096283092
# Episode 95 best score till now -629.2442379857573 average score for the past 100ep -1129.3392786733737
# Episode 96 best score till now -629.2442379857573 average score for the past 100ep -1127.1923007364546
# Episode 97 best score till now -629.2442379857573 average score for the past 100ep -1124.2897392119037
# Episode 98 best score till now -629.2442379857573 average score for the past 100ep -1121.775303063303
# Episode 99 best score till now -629.2442379857573 average score for the past 100ep -1121.4686969550949
# Episode 100 best score till now -629.2442379857573 average score for the past 100ep -1123.6403082667018
# Episode 101 best score till now -629.2442379857573 average score for the past 100ep -1113.453393710436
# Episode 102 best score till now -629.2442379857573 average score for the past 100ep -1104.3913060028533
# Episode 103 best score till now -629.2442379857573 average score for the past 100ep -1095.0370674250228
# Episode 104 best score till now -629.2442379857573 average score for the past 100ep -1089.3587669884664
# Episode 105 best score till now -629.2442379857573 average score for the past 100ep -1082.287109576363
# Episode 106 best score till now -629.2442379857573 average score for the past 100ep -1073.609483959894
# Episode 107 best score till now -629.2442379857573 average score for the past 100ep -1066.600114173936
# Episode 108 best score till now -629.2442379857573 average score for the past 100ep -1059.5373604699068
# Episode 109 best score till now -629.2442379857573 average score for the past 100ep -1050.671144793843
# Episode 110 best score till now -629.2442379857573 average score for the past 100ep -1045.574581396887
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 111 best score till now -536.5942466667767 average score for the past 100ep -1034.459676059412
# Episode 112 best score till now -536.5942466667767 average score for the past 100ep -1022.638482244625
# Episode 113 best score till now -536.5942466667767 average score for the past 100ep -1012.4769568810354
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 114 best score till now -503.59538111214215 average score for the past 100ep -1003.7944832200395
# Episode 115 best score till now -503.59538111214215 average score for the past 100ep -996.4262468711012
# Episode 116 best score till now -503.59538111214215 average score for the past 100ep -989.7191385904827
# Episode 117 best score till now -503.59538111214215 average score for the past 100ep -986.6383552709226
# Episode 118 best score till now -503.59538111214215 average score for the past 100ep -981.0725242641637
# Episode 119 best score till now -503.59538111214215 average score for the past 100ep -976.4889435710901
# Episode 120 best score till now -503.59538111214215 average score for the past 100ep -970.2902082922463
# Episode 121 best score till now -503.59538111214215 average score for the past 100ep -964.736631830464
# Episode 122 best score till now -503.59538111214215 average score for the past 100ep -962.7188529080616
# Episode 123 best score till now -503.59538111214215 average score for the past 100ep -955.8522462558464
# Episode 124 best score till now -503.59538111214215 average score for the past 100ep -952.7825912058282
# Episode 125 best score till now -503.59538111214215 average score for the past 100ep -947.5901887037488
# Episode 126 best score till now -503.59538111214215 average score for the past 100ep -941.8257369728994
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 127 best score till now -501.33421592984274 average score for the past 100ep -936.0106367218275
# Episode 128 best score till now -501.33421592984274 average score for the past 100ep -930.5067404564466
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 129 best score till now -244.38542520769792 average score for the past 100ep -923.2862677500899
# Episode 130 best score till now -244.38542520769792 average score for the past 100ep -918.5772728618317
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 131 best score till now -120.22871266339921 average score for the past 100ep -908.7970128936967
# Episode 132 best score till now -120.22871266339921 average score for the past 100ep -899.9190043128704
# Episode 133 best score till now -120.22871266339921 average score for the past 100ep -891.3727457432079
# Episode 134 best score till now -120.22871266339921 average score for the past 100ep -889.3076795665022
# Episode 135 best score till now -120.22871266339921 average score for the past 100ep -887.3011938280927
# Episode 136 best score till now -120.22871266339921 average score for the past 100ep -879.9655745404103
# Episode 137 best score till now -120.22871266339921 average score for the past 100ep -871.3235983324693
# Episode 138 best score till now -120.22871266339921 average score for the past 100ep -865.1950168245482
# Episode 139 best score till now -120.22871266339921 average score for the past 100ep -858.9555804988537
# Episode 140 best score till now -120.22871266339921 average score for the past 100ep -854.0422195475898
# Episode 141 best score till now -120.22871266339921 average score for the past 100ep -850.0185617302566
# Episode 142 best score till now -120.22871266339921 average score for the past 100ep -843.2288085773757
# Episode 143 best score till now -120.22871266339921 average score for the past 100ep -835.7580853680269
# Episode 144 best score till now -120.22871266339921 average score for the past 100ep -833.2550979394126
# Episode 145 best score till now -120.22871266339921 average score for the past 100ep -834.3979279093678
# Episode 146 best score till now -120.22871266339921 average score for the past 100ep -827.8572565968038
# Episode 147 best score till now -120.22871266339921 average score for the past 100ep -823.3317610585474
# Episode 148 best score till now -120.22871266339921 average score for the past 100ep -818.2466461127941
# Episode 149 best score till now -120.22871266339921 average score for the past 100ep -818.6769612085336
# Episode 150 best score till now -120.22871266339921 average score for the past 100ep -809.5670302790475
# Episode 151 best score till now -120.22871266339921 average score for the past 100ep -813.0446590725064
# Episode 152 best score till now -120.22871266339921 average score for the past 100ep -807.6254670476643
# Episode 153 best score till now -120.22871266339921 average score for the past 100ep -801.1331990305177
# Episode 154 best score till now -120.22871266339921 average score for the past 100ep -795.4627003746932
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 155 best score till now -0.2705568408738315 average score for the past 100ep -785.3823317785697
# Episode 156 best score till now -0.2705568408738315 average score for the past 100ep -776.8562194750979
# Episode 157 best score till now -0.2705568408738315 average score for the past 100ep -768.3223883891594
# Episode 158 best score till now -0.2705568408738315 average score for the past 100ep -761.7230164040901
# Episode 159 best score till now -0.2705568408738315 average score for the past 100ep -755.3238247593243
# Episode 160 best score till now -0.2705568408738315 average score for the past 100ep -749.8358338282892
# Episode 161 best score till now -0.2705568408738315 average score for the past 100ep -740.9341456575441
# Episode 162 best score till now -0.2705568408738315 average score for the past 100ep -734.5574112543757
# Episode 163 best score till now -0.2705568408738315 average score for the past 100ep -729.1704197244729
# Episode 164 best score till now -0.2705568408738315 average score for the past 100ep -718.5011703684072
# Episode 165 best score till now -0.2705568408738315 average score for the past 100ep -711.9926970792163
# Episode 166 best score till now -0.2705568408738315 average score for the past 100ep -704.1970339202167
# Episode 167 best score till now -0.2705568408738315 average score for the past 100ep -693.7512266175747
# Episode 168 best score till now -0.2705568408738315 average score for the past 100ep -683.5869682276274
# Episode 169 best score till now -0.2705568408738315 average score for the past 100ep -674.3220351833163
# Episode 170 best score till now -0.2705568408738315 average score for the past 100ep -665.5369942251102
# Episode 171 best score till now -0.2705568408738315 average score for the past 100ep -655.0610956254155
# Episode 172 best score till now -0.2705568408738315 average score for the past 100ep -645.4197662820646
# Episode 173 best score till now -0.2705568408738315 average score for the past 100ep -644.3612250118895
# Episode 174 best score till now -0.2705568408738315 average score for the past 100ep -636.3303866035576
# Episode 175 best score till now -0.2705568408738315 average score for the past 100ep -625.8307876286469
# Episode 176 best score till now -0.2705568408738315 average score for the past 100ep -615.8704525622059
# Episode 177 best score till now -0.2705568408738315 average score for the past 100ep -605.8028144383941
# Episode 178 best score till now -0.2705568408738315 average score for the past 100ep -595.4258905881718
# Episode 179 best score till now -0.2705568408738315 average score for the past 100ep -586.6984407931079
# Episode 180 best score till now -0.2705568408738315 average score for the past 100ep -578.9097992846238
# Episode 181 best score till now -0.2705568408738315 average score for the past 100ep -570.0185237764462
# Episode 182 best score till now -0.2705568408738315 average score for the past 100ep -562.3371875813624
# Episode 183 best score till now -0.2705568408738315 average score for the past 100ep -555.781469309818
# Episode 184 best score till now -0.2705568408738315 average score for the past 100ep -552.4454891462772
# Episode 185 best score till now -0.2705568408738315 average score for the past 100ep -544.8550891726114
# Episode 186 best score till now -0.2705568408738315 average score for the past 100ep -542.4622166225934
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 187 best score till now -0.11822416612420071 average score for the past 100ep -532.3886274510326
# Episode 188 best score till now -0.11822416612420071 average score for the past 100ep -528.2939711085705
# Episode 189 best score till now -0.11822416612420071 average score for the past 100ep -520.6847848274333
# Episode 190 best score till now -0.11822416612420071 average score for the past 100ep -515.5402613568934
# Episode 191 best score till now -0.11822416612420071 average score for the past 100ep -507.6562622395371
# Episode 192 best score till now -0.11822416612420071 average score for the past 100ep -496.5924352433444
# Episode 193 best score till now -0.11822416612420071 average score for the past 100ep -493.49409850378333
# Episode 194 best score till now -0.11822416612420071 average score for the past 100ep -487.1918502813593
# Episode 195 best score till now -0.11822416612420071 average score for the past 100ep -479.6666335365376
# Episode 196 best score till now -0.11822416612420071 average score for the past 100ep -471.70191403345666
# Episode 197 best score till now -0.11822416612420071 average score for the past 100ep -468.143230906203
# Episode 198 best score till now -0.11822416612420071 average score for the past 100ep -459.3933827058174
# Episode 199 best score till now -0.11822416612420071 average score for the past 100ep -449.72228265100256
# Episode 200 best score till now -0.11822416612420071 average score for the past 100ep -440.18548002342084
# Episode 201 best score till now -0.11822416612420071 average score for the past 100ep -434.1020147735785
# Episode 202 best score till now -0.11822416612420071 average score for the past 100ep -429.9884050263614
# Episode 203 best score till now -0.11822416612420071 average score for the past 100ep -424.256803135667
# Episode 204 best score till now -0.11822416612420071 average score for the past 100ep -417.0400451913483
# Episode 205 best score till now -0.11822416612420071 average score for the past 100ep -410.7448968474257
# Episode 206 best score till now -0.11822416612420071 average score for the past 100ep -408.0090731459075
# Episode 207 best score till now -0.11822416612420071 average score for the past 100ep -400.5124263913107
# Episode 208 best score till now -0.11822416612420071 average score for the past 100ep -392.85921156909336
# Episode 209 best score till now -0.11822416612420071 average score for the past 100ep -385.61323810820335
# Episode 210 best score till now -0.11822416612420071 average score for the past 100ep -378.4790394937188
# Episode 211 best score till now -0.11822416612420071 average score for the past 100ep -377.8843042886276
# Episode 212 best score till now -0.11822416612420071 average score for the past 100ep -375.30550115175373
# Episode 213 best score till now -0.11822416612420071 average score for the past 100ep -368.8961532253181
# Episode 214 best score till now -0.11822416612420071 average score for the past 100ep -365.10867533070245
# Episode 215 best score till now -0.11822416612420071 average score for the past 100ep -360.1237177976581
# Episode 216 best score till now -0.11822416612420071 average score for the past 100ep -353.8794820613766
# Episode 217 best score till now -0.11822416612420071 average score for the past 100ep -346.5262203002171
# Episode 218 best score till now -0.11822416612420071 average score for the past 100ep -341.2986361939461
# Episode 219 best score till now -0.11822416612420071 average score for the past 100ep -337.5890171116526
# Episode 220 best score till now -0.11822416612420071 average score for the past 100ep -332.5383273504411
# Episode 221 best score till now -0.11822416612420071 average score for the past 100ep -330.1676105330346
# Episode 222 best score till now -0.11822416612420071 average score for the past 100ep -322.66812514422924
# Episode 223 best score till now -0.11822416612420071 average score for the past 100ep -321.8118233154327
# Episode 224 best score till now -0.11822416612420071 average score for the past 100ep -313.7537884625835
# Episode 225 best score till now -0.11822416612420071 average score for the past 100ep -312.58349227856064
# Episode 226 best score till now -0.11822416612420071 average score for the past 100ep -306.49367445175045
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# saving checkpoints ....
# checkpoint saved ..
# Episode 227 best score till now -0.10587543367834612 average score for the past 100ep -301.4813910467888
# Episode 228 best score till now -0.10587543367834612 average score for the past 100ep -303.48458789145207
# Episode 229 best score till now -0.10587543367834612 average score for the past 100ep -305.8597451213454
# Episode 230 best score till now -0.10587543367834612 average score for the past 100ep -299.6376536610912
# Episode 231 best score till now -0.10587543367834612 average score for the past 100ep -299.67684476485806
# Episode 232 best score till now -0.10587543367834612 average score for the past 100ep -303.3565855401357
# Episode 233 best score till now -0.10587543367834612 average score for the past 100ep -306.9211378915109
# Episode 234 best score till now -0.10587543367834612 average score for the past 100ep -306.6932449447169
# Episode 235 best score till now -0.10587543367834612 average score for the past 100ep -303.4933948254371
# Episode 236 best score till now -0.10587543367834612 average score for the past 100ep -303.48800314763355
# Episode 237 best score till now -0.10587543367834612 average score for the past 100ep -302.29820048552773
# Episode 238 best score till now -0.10587543367834612 average score for the past 100ep -302.2455526871114
# Episode 239 best score till now -0.10587543367834612 average score for the past 100ep -304.5679710447965
# Episode 240 best score till now -0.10587543367834612 average score for the past 100ep -303.3541294432164
# Episode 241 best score till now -0.10587543367834612 average score for the past 100ep -304.5174416131795
# Episode 242 best score till now -0.10587543367834612 average score for the past 100ep -300.8841126720691
# Episode 243 best score till now -0.10587543367834612 average score for the past 100ep -305.3861470269139
# Episode 244 best score till now -0.10587543367834612 average score for the past 100ep -300.6744735029432
# Episode 245 best score till now -0.10587543367834612 average score for the past 100ep -296.9130174648823
# Episode 246 best score till now -0.10587543367834612 average score for the past 100ep -294.50498717432316
# Episode 247 best score till now -0.10587543367834612 average score for the past 100ep -292.00598840232817
# Episode 248 best score till now -0.10587543367834612 average score for the past 100ep -289.6350662766317
# Episode 249 best score till now -0.10587543367834612 average score for the past 100ep -283.44781543698383
# Episode 250 best score till now -0.10587543367834612 average score for the past 100ep -287.98069193557745
# Episode 251 best score till now -0.10587543367834612 average score for the past 100ep -280.6652728066814
# Episode 252 best score till now -0.10587543367834612 average score for the past 100ep -280.6174581606637
# Episode 253 best score till now -0.10587543367834612 average score for the past 100ep -278.3348367541805
# Episode 254 best score till now -0.10587543367834612 average score for the past 100ep -278.31000039298175
# Episode 255 best score till now -0.10587543367834612 average score for the past 100ep -281.96488053700386
# Episode 256 best score till now -0.10587543367834612 average score for the past 100ep -280.70606845533524
# Episode 257 best score till now -0.10587543367834612 average score for the past 100ep -278.33686653183196
# Episode 258 best score till now -0.10587543367834612 average score for the past 100ep -274.7449256286498
# Episode 259 best score till now -0.10587543367834612 average score for the past 100ep -275.9692906421688
# Episode 260 best score till now -0.10587543367834612 average score for the past 100ep -275.8883034084662
# Episode 261 best score till now -0.10587543367834612 average score for the past 100ep -274.7049296294588
# Episode 262 best score till now -0.10587543367834612 average score for the past 100ep -270.63471338554547
# Episode 263 best score till now -0.10587543367834612 average score for the past 100ep -267.9449385779746
# Episode 264 best score till now -0.10587543367834612 average score for the past 100ep -269.0620105445821
# Episode 265 best score till now -0.10587543367834612 average score for the past 100ep -265.5493251437223
# Episode 266 best score till now -0.10587543367834612 average score for the past 100ep -263.1731932893198
# Episode 267 best score till now -0.10587543367834612 average score for the past 100ep -263.17481467696643
# Episode 268 best score till now -0.10587543367834612 average score for the past 100ep -263.16773861517004
# Episode 269 best score till now -0.10587543367834612 average score for the past 100ep -264.3705316120538
# Episode 270 best score till now -0.10587543367834612 average score for the past 100ep -261.91246127431805
# Episode 271 best score till now -0.10587543367834612 average score for the past 100ep -261.90523633166066
# Episode 272 best score till now -0.10587543367834612 average score for the past 100ep -261.96672731582004
# Episode 273 best score till now -0.10587543367834612 average score for the past 100ep -252.0028532218122
# Episode 274 best score till now -0.10587543367834612 average score for the past 100ep -250.86895814464242
# Episode 275 best score till now -0.10587543367834612 average score for the past 100ep -253.57324060777228
# Episode 276 best score till now -0.10587543367834612 average score for the past 100ep -253.5435525342774
# Episode 277 best score till now -0.10587543367834612 average score for the past 100ep -254.72495213275621
# Episode 278 best score till now -0.10587543367834612 average score for the past 100ep -257.0813080383181
# Episode 279 best score till now -0.10587543367834612 average score for the past 100ep -257.1047672083459
# Episode 280 best score till now -0.10587543367834612 average score for the past 100ep -255.861765862111
# Episode 281 best score till now -0.10587543367834612 average score for the past 100ep -254.74234755802274
# Episode 282 best score till now -0.10587543367834612 average score for the past 100ep -254.65923182267727
# Episode 283 best score till now -0.10587543367834612 average score for the past 100ep -253.45204707764228
# Episode 284 best score till now -0.10587543367834612 average score for the past 100ep -248.1670571236672
# Episode 285 best score till now -0.10587543367834612 average score for the past 100ep -252.23232197986403
# Episode 286 best score till now -0.10587543367834612 average score for the past 100ep -247.31673871860733
# Episode 287 best score till now -0.10587543367834612 average score for the past 100ep -252.2249480916892
# Episode 288 best score till now -0.10587543367834612 average score for the past 100ep -253.4983410290531
# Episode 289 best score till now -0.10587543367834612 average score for the past 100ep -257.59526161662967
# Episode 290 best score till now -0.10587543367834612 average score for the past 100ep -259.96069796572993
# Episode 291 best score till now -0.10587543367834612 average score for the past 100ep -261.1264095240587
# Episode 292 best score till now -0.10587543367834612 average score for the past 100ep -263.5157700058053
# Episode 293 best score till now -0.10587543367834612 average score for the past 100ep -262.90413034219375
# Episode 294 best score till now -0.10587543367834612 average score for the past 100ep -266.7355618176807
# Episode 295 best score till now -0.10587543367834612 average score for the past 100ep -266.7530745347287
# Episode 296 best score till now -0.10587543367834612 average score for the past 100ep -266.7017916821937
# Episode 297 best score till now -0.10587543367834612 average score for the past 100ep -264.2038157170625
# Episode 298 best score till now -0.10587543367834612 average score for the past 100ep -265.41610321012513
# Episode 299 best score till now -0.10587543367834612 average score for the past 100ep -265.41626604425676
# Episode 300 best score till now -0.10587543367834612 average score for the past 100ep -265.3774580591023
# Episode 301 best score till now -0.10587543367834612 average score for the past 100ep -263.031566341961
# Episode 302 best score till now -0.10587543367834612 average score for the past 100ep -260.713562472763
# Episode 303 best score till now -0.10587543367834612 average score for the past 100ep -259.607130998535
# Episode 304 best score till now -0.10587543367834612 average score for the past 100ep -260.74474259943617
# Episode 305 best score till now -0.10587543367834612 average score for the past 100ep -264.4048985723607
# Episode 306 best score till now -0.10587543367834612 average score for the past 100ep -262.4706930490269
# Episode 307 best score till now -0.10587543367834612 average score for the past 100ep -261.25690240311906
# Episode 308 best score till now -0.10587543367834612 average score for the past 100ep -266.1277505028855
# Episode 309 best score till now -0.10587543367834612 average score for the past 100ep -266.1215281134388
# Episode 310 best score till now -0.10587543367834612 average score for the past 100ep -268.83468918086805
# Episode 311 best score till now -0.10587543367834612 average score for the past 100ep -269.41652428226257
# Episode 312 best score till now -0.10587543367834612 average score for the past 100ep -268.1748510945276
# Episode 313 best score till now -0.10587543367834612 average score for the past 100ep -266.9923300110481
# Episode 314 best score till now -0.10587543367834612 average score for the past 100ep -266.9784189639171
# Episode 315 best score till now -0.10587543367834612 average score for the past 100ep -265.7645685759424
# Episode 316 best score till now -0.10587543367834612 average score for the past 100ep -265.80814448921296
# Episode 317 best score till now -0.10587543367834612 average score for the past 100ep -263.47421388659063
# Episode 318 best score till now -0.10587543367834612 average score for the past 100ep -264.695886341105
# Episode 319 best score till now -0.10587543367834612 average score for the past 100ep -263.86383730438837
# Episode 320 best score till now -0.10587543367834612 average score for the past 100ep -265.06742862563226
# Episode 321 best score till now -0.10587543367834612 average score for the past 100ep -262.4316913550982
# Episode 322 best score till now -0.10587543367834612 average score for the past 100ep -262.4163508607488
# Episode 323 best score till now -0.10587543367834612 average score for the past 100ep -260.6121544823879
# Episode 324 best score till now -0.10587543367834612 average score for the past 100ep -260.64219693687613
# Episode 325 best score till now -0.10587543367834612 average score for the past 100ep -259.4311981449479
# Episode 326 best score till now -0.10587543367834612 average score for the past 100ep -260.6298412719548
# Episode 327 best score till now -0.10587543367834612 average score for the past 100ep -261.8894162516065
# Episode 328 best score till now -0.10587543367834612 average score for the past 100ep -257.1748616671668
# Episode 329 best score till now -0.10587543367834612 average score for the past 100ep -255.91959459911
# Episode 330 best score till now -0.10587543367834612 average score for the past 100ep -257.0529246687648
# Episode 331 best score till now -0.10587543367834612 average score for the past 100ep -257.03565086005256
# Episode 332 best score till now -0.10587543367834612 average score for the past 100ep -253.33314602736442
# Episode 333 best score till now -0.10587543367834612 average score for the past 100ep -253.1518364286542
# Episode 334 best score till now -0.10587543367834612 average score for the past 100ep -248.0211708109664
# Episode 335 best score till now -0.10587543367834612 average score for the past 100ep -247.98337529108068
# Episode 336 best score till now -0.10587543367834612 average score for the past 100ep -247.91185569640493
# Episode 337 best score till now -0.10587543367834612 average score for the past 100ep -249.06739560473875
# Episode 338 best score till now -0.10587543367834612 average score for the past 100ep -249.09801929730665
# Episode 339 best score till now -0.10587543367834612 average score for the past 100ep -245.57451734718606
# Episode 340 best score till now -0.10587543367834612 average score for the past 100ep -243.18873604877652
# Episode 341 best score till now -0.10587543367834612 average score for the past 100ep -240.84229447574762
# Episode 342 best score till now -0.10587543367834612 average score for the past 100ep -243.2838175984668
# Episode 343 best score till now -0.10587543367834612 average score for the past 100ep -241.111041323557
# Episode 344 best score till now -0.10587543367834612 average score for the past 100ep -241.08137893585365
# Episode 345 best score till now -0.10587543367834612 average score for the past 100ep -240.80022356875335
# Episode 346 best score till now -0.10587543367834612 average score for the past 100ep -239.60082729630489
# Episode 347 best score till now -0.10587543367834612 average score for the past 100ep -238.5245778869961
# Episode 348 best score till now -0.10587543367834612 average score for the past 100ep -239.73365560419262
# Episode 349 best score till now -0.10587543367834612 average score for the past 100ep -239.6716543187665
# Episode 350 best score till now -0.10587543367834612 average score for the past 100ep -235.12683915351244
# Episode 351 best score till now -0.10587543367834612 average score for the past 100ep -233.90815666762535
# Episode 352 best score till now -0.10587543367834612 average score for the past 100ep -231.5904569337576
# Episode 353 best score till now -0.10587543367834612 average score for the past 100ep -230.41588991660163
# Episode 354 best score till now -0.10587543367834612 average score for the past 100ep -226.92049363036966
# Episode 355 best score till now -0.10587543367834612 average score for the past 100ep -229.17018927538092
# Episode 356 best score till now -0.10587543367834612 average score for the past 100ep -234.1610447808948
# Episode 357 best score till now -0.10587543367834612 average score for the past 100ep -237.72633488145672
# Episode 358 best score till now -0.10587543367834612 average score for the past 100ep -240.0792352036729
# Episode 359 best score till now -0.10587543367834612 average score for the past 100ep -240.00519179961194
# Episode 360 best score till now -0.10587543367834612 average score for the past 100ep -237.63686111438824
# Episode 361 best score till now -0.10587543367834612 average score for the past 100ep -237.62820251263648
# Episode 362 best score till now -0.10587543367834612 average score for the past 100ep -237.56351298136428
# Episode 363 best score till now -0.10587543367834612 average score for the past 100ep -235.1992896521591
# Episode 364 best score till now -0.10587543367834612 average score for the past 100ep -236.38902788523686
# Episode 365 best score till now -0.10587543367834612 average score for the past 100ep -236.38000077233025
# Episode 366 best score till now -0.10587543367834612 average score for the past 100ep -236.37864479137153
# Episode 367 best score till now -0.10587543367834612 average score for the past 100ep -236.35631020197383
# Episode 368 best score till now -0.10587543367834612 average score for the past 100ep -236.31954703442045
# Episode 369 best score till now -0.10587543367834612 average score for the past 100ep -233.93086358102818
# Episode 370 best score till now -0.10587543367834612 average score for the past 100ep -235.1556407734731
# Episode 371 best score till now -0.10587543367834612 average score for the past 100ep -235.15263658845586
# Episode 372 best score till now -0.10587543367834612 average score for the past 100ep -238.8130828287731
# Episode 373 best score till now -0.10587543367834612 average score for the past 100ep -240.04213984601768
# Episode 374 best score till now -0.10587543367834612 average score for the past 100ep -238.80858402760987
# Episode 375 best score till now -0.10587543367834612 average score for the past 100ep -234.97618849559825
# Episode 376 best score till now -0.10587543367834612 average score for the past 100ep -234.9979261139302
# Episode 377 best score till now -0.10587543367834612 average score for the past 100ep -233.8168097407965
# Episode 378 best score till now -0.10587543367834612 average score for the past 100ep -230.21673044635375
# Episode 379 best score till now -0.10587543367834612 average score for the past 100ep -229.09703727550678
# Episode 380 best score till now -0.10587543367834612 average score for the past 100ep -229.08164395100295
# Episode 381 best score till now -0.10587543367834612 average score for the past 100ep -229.09368160041245
# Episode 382 best score till now -0.10587543367834612 average score for the past 100ep -231.64977085555165
# Episode 383 best score till now -0.10587543367834612 average score for the past 100ep -232.86874698992062
# Episode 384 best score till now -0.10587543367834612 average score for the past 100ep -235.2544795740027
# Episode 385 best score till now -0.10587543367834612 average score for the past 100ep -231.18965309460677
# Episode 386 best score till now -0.10587543367834612 average score for the past 100ep -231.15014893688078
# Episode 387 best score till now -0.10587543367834612 average score for the past 100ep -227.4677122256663
# Episode 388 best score till now -0.10587543367834612 average score for the past 100ep -225.11117454521073
# Episode 389 best score till now -0.10587543367834612 average score for the past 100ep -222.21672997304395
# Episode 390 best score till now -0.10587543367834612 average score for the past 100ep -220.93947445036534
# Episode 391 best score till now -0.10587543367834612 average score for the past 100ep -224.82807881285572
# Episode 392 best score till now -0.10587543367834612 average score for the past 100ep -226.0789485568711
# Episode 393 best score till now -0.10587543367834612 average score for the past 100ep -222.7517231891397
# Episode 394 best score till now -0.10587543367834612 average score for the past 100ep -218.97034535138994
# Episode 395 best score till now -0.10587543367834612 average score for the past 100ep -220.12324171233814
# Episode 396 best score till now -0.10587543367834612 average score for the past 100ep -223.77888660857963
# Episode 397 best score till now -0.10587543367834612 average score for the past 100ep -222.6679820538461
# Episode 398 best score till now -0.10587543367834612 average score for the past 100ep -223.787053732859
# Episode 399 best score till now -0.10587543367834612 average score for the past 100ep -226.16649372148606
# Episode 400 best score till now -0.10587543367834612 average score for the past 100ep -226.17049209170244
# Episode 401 best score till now -0.10587543367834612 average score for the past 100ep -227.35747531230498
# Episode 402 best score till now -0.10587543367834612 average score for the past 100ep -227.32890656423743
# Episode 403 best score till now -0.10587543367834612 average score for the past 100ep -227.3069744064861
# Episode 404 best score till now -0.10587543367834612 average score for the past 100ep -228.5650746397062
# Episode 405 best score till now -0.10587543367834612 average score for the past 100ep -228.4769044269373
# Episode 406 best score till now -0.10587543367834612 average score for the past 100ep -229.86452148824222
# Episode 407 best score till now -0.10587543367834612 average score for the past 100ep -231.07572712019206
# Episode 408 best score till now -0.10587543367834612 average score for the past 100ep -229.70354486726075
# Episode 409 best score till now -0.10587543367834612 average score for the past 100ep -228.52240289652468
# Episode 410 best score till now -0.10587543367834612 average score for the past 100ep -224.73608608836116
# Episode 411 best score till now -0.10587543367834612 average score for the past 100ep -221.82758318152162
# Episode 412 best score till now -0.10587543367834612 average score for the past 100ep -220.70235479122599
# Episode 413 best score till now -0.10587543367834612 average score for the past 100ep -224.26744991041366
# Episode 414 best score till now -0.10587543367834612 average score for the past 100ep -224.27647550604965
# Episode 415 best score till now -0.10587543367834612 average score for the past 100ep -229.21988787978134
# Episode 416 best score till now -0.10587543367834612 average score for the past 100ep -233.3800509347371
# Episode 417 best score till now -0.10587543367834612 average score for the past 100ep -234.62368068670796
# Episode 418 best score till now -0.10587543367834612 average score for the past 100ep -235.75965683053627
# Episode 419 best score till now -0.10587543367834612 average score for the past 100ep -235.54980616421716
# Episode 420 best score till now -0.10587543367834612 average score for the past 100ep -234.41078540902583
# Episode 421 best score till now -0.10587543367834612 average score for the past 100ep -236.7292345007726
# Episode 422 best score till now -0.10587543367834612 average score for the past 100ep -241.19341466391407
# Episode 423 best score till now -0.10587543367834612 average score for the past 100ep -237.67713834415645
# Episode 424 best score till now -0.10587543367834612 average score for the past 100ep -238.77545918018055
# Episode 425 best score till now -0.10587543367834612 average score for the past 100ep -236.4647664692616
# Episode 426 best score till now -0.10587543367834612 average score for the past 100ep -235.27558090883767
# Episode 427 best score till now -0.10587543367834612 average score for the past 100ep -235.22914368470356
# Episode 428 best score till now -0.10587543367834612 average score for the past 100ep -234.10906044685703
# Episode 429 best score till now -0.10587543367834612 average score for the past 100ep -231.76994529374332
# Episode 430 best score till now -0.10587543367834612 average score for the past 100ep -230.65989656939823
# Episode 431 best score till now -0.10587543367834612 average score for the past 100ep -234.318189565632
# Episode 432 best score till now -0.10587543367834612 average score for the past 100ep -236.67476046875535
# ...
# Episode 1306 best score till now -0.10587543367834612 average score for the past 100ep -213.53298470668977
# Episode 1307 best score till now -0.10587543367834612 average score for the past 100ep -214.7149466055218
# Episode 1308 best score till now -0.10587543367834612 average score for the past 100ep -215.91571865894238
# Episode 1309 best score till now -0.10587543367834612 average score for the past 100ep -217.05758676285342
# Episode 1310 best score till now -0.10587543367834612 average score for the past 100ep -219.4224275513921
# Episode 1311 best score till now -0.10587543367834612 average score for the past 100ep -217.04728959608462
# Episode 1312 best score till now -0.10587543367834612 average score for the past 100ep -213.50572161248343
# Episode 1313 best score till now -0.10587543367834612 average score for the past 100ep -211.25089825884382
# Episode 1314 best score till now -0.10587543367834612 average score for the past 100ep -214.769546346471
# Episode 1315 best score till now -0.10587543367834612 average score for the past 100ep -216.0257493718629
# Episode 1316 best score till now -0.10587543367834612 average score for the past 100ep -217.22937890087277
# Episode 1317 best score till now -0.10587543367834612 average score for the past 100ep -217.20541260492973
# Episode 1318 best score till now -0.10587543367834612 average score for the past 100ep -217.25837248640593
# Episode 1319 best score till now -0.10587543367834612 average score for the past 100ep -213.7396263291841
# Episode 1320 best score till now -0.10587543367834612 average score for the past 100ep -213.71886787418117
# Episode 1321 best score till now -0.10587543367834612 average score for the past 100ep -213.74307708178665
# Episode 1322 best score till now -0.10587543367834612 average score for the past 100ep -213.75524466409883
# Episode 1323 best score till now -0.10587543367834612 average score for the past 100ep -215.07818809648498
# Episode 1324 best score till now -0.10587543367834612 average score for the past 100ep -215.09944331268812
# Episode 1325 best score till now -0.10587543367834612 average score for the past 100ep -213.8589291247954
# Episode 1326 best score till now -0.10587543367834612 average score for the past 100ep -212.65718102689732
# Episode 1327 best score till now -0.10587543367834612 average score for the past 100ep -217.4115720549176
# Episode 1328 best score till now -0.10587543367834612 average score for the past 100ep -218.6143485857339
# Episode 1329 best score till now -0.10587543367834612 average score for the past 100ep -218.60665346383792
# Episode 1330 best score till now -0.10587543367834612 average score for the past 100ep -221.01325384003044
# Episode 1331 best score till now -0.10587543367834612 average score for the past 100ep -222.21835288076784
# Episode 1332 best score till now -0.10587543367834612 average score for the past 100ep -221.05319871377623
# Episode 1333 best score till now -0.10587543367834612 average score for the past 100ep -223.45354088795415
# Episode 1334 best score till now -0.10587543367834612 average score for the past 100ep -224.57268469659087
# Episode 1335 best score till now -0.10587543367834612 average score for the past 100ep -226.896763990569
# Episode 1336 best score till now -0.10587543367834612 average score for the past 100ep -228.07331885281152
# Episode 1337 best score till now -0.10587543367834612 average score for the past 100ep -228.12216603979778
# Episode 1338 best score till now -0.10587543367834612 average score for the past 100ep -229.32581991527687
# Episode 1339 best score till now -0.10587543367834612 average score for the past 100ep -230.48133027415324
# Episode 1340 best score till now -0.10587543367834612 average score for the past 100ep -234.25924882322775
# Episode 1341 best score till now -0.10587543367834612 average score for the past 100ep -236.61850795846988
# Episode 1342 best score till now -0.10587543367834612 average score for the past 100ep -237.79562591498856
# Episode 1343 best score till now -0.10587543367834612 average score for the past 100ep -240.26049072782345
# Episode 1344 best score till now -0.10587543367834612 average score for the past 100ep -241.43577106862153
# Episode 1345 best score till now -0.10587543367834612 average score for the past 100ep -244.71077881158948
# Episode 1346 best score till now -0.10587543367834612 average score for the past 100ep -247.07148469780816
# Episode 1347 best score till now -0.10587543367834612 average score for the past 100ep -248.16620898660693
# Episode 1348 best score till now -0.10587543367834612 average score for the past 100ep -243.49835572784593
# Episode 1349 best score till now -0.10587543367834612 average score for the past 100ep -243.50723936014893
# Episode 1350 best score till now -0.10587543367834612 average score for the past 100ep -242.04767027332827
# Episode 1351 best score till now -0.10587543367834612 average score for the past 100ep -242.03320927801335
# Episode 1352 best score till now -0.10587543367834612 average score for the past 100ep -244.24807864124236
# Episode 1353 best score till now -0.10587543367834612 average score for the past 100ep -246.6584059567506
# Episode 1354 best score till now -0.10587543367834612 average score for the past 100ep -246.7418915811344
# Episode 1355 best score till now -0.10587543367834612 average score for the past 100ep -243.15924530716495
# Episode 1356 best score till now -0.10587543367834612 average score for the past 100ep -243.25824936536182
# Episode 1357 best score till now -0.10587543367834612 average score for the past 100ep -240.80681255802705
# Episode 1358 best score till now -0.10587543367834612 average score for the past 100ep -242.61136449201354
# Episode 1359 best score till now -0.10587543367834612 average score for the past 100ep -240.24739468230894
# Episode 1360 best score till now -0.10587543367834612 average score for the past 100ep -241.42704369683813
# Episode 1361 best score till now -0.10587543367834612 average score for the past 100ep -241.424115248089
# Episode 1362 best score till now -0.10587543367834612 average score for the past 100ep -241.4056530535911
# Episode 1363 best score till now -0.10587543367834612 average score for the past 100ep -241.41702650656148
# Episode 1364 best score till now -0.10587543367834612 average score for the past 100ep -245.03778837577937
# Episode 1365 best score till now -0.10587543367834612 average score for the past 100ep -243.82522204337567
# Episode 1366 best score till now -0.10587543367834612 average score for the past 100ep -243.7699654829776
# Episode 1367 best score till now -0.10587543367834612 average score for the past 100ep -246.22084447368107
# Episode 1368 best score till now -0.10587543367834612 average score for the past 100ep -248.61000375095725
# Episode 1369 best score till now -0.10587543367834612 average score for the past 100ep -248.62794815997458
# Episode 1370 best score till now -0.10587543367834612 average score for the past 100ep -248.56870194554102
# Episode 1371 best score till now -0.10587543367834612 average score for the past 100ep -249.7932636514346
# Episode 1372 best score till now -0.10587543367834612 average score for the past 100ep -252.18256200666582
# Episode 1373 best score till now -0.10587543367834612 average score for the past 100ep -253.44771113798407
# Episode 1374 best score till now -0.10587543367834612 average score for the past 100ep -249.82834867014972
# Episode 1375 best score till now -0.10587543367834612 average score for the past 100ep -250.96308121826297
# Episode 1376 best score till now -0.10587543367834612 average score for the past 100ep -249.75754511341046
# Episode 1377 best score till now -0.10587543367834612 average score for the past 100ep -252.1297275907218
# Episode 1378 best score till now -0.10587543367834612 average score for the past 100ep -249.69275667841535
# Episode 1379 best score till now -0.10587543367834612 average score for the past 100ep -250.90609083343762
# Episode 1380 best score till now -0.10587543367834612 average score for the past 100ep -250.93793331113466
# Episode 1381 best score till now -0.10587543367834612 average score for the past 100ep -250.87774224892587
# Episode 1382 best score till now -0.10587543367834612 average score for the past 100ep -247.25607178719943
# Episode 1383 best score till now -0.10587543367834612 average score for the past 100ep -248.46383139086743
# Episode 1384 best score till now -0.10587543367834612 average score for the past 100ep -249.64145415596397
# Episode 1385 best score till now -0.10587543367834612 average score for the past 100ep -253.0446050931433
# Episode 1386 best score till now -0.10587543367834612 average score for the past 100ep -250.79478711601715
# Episode 1387 best score till now -0.10587543367834612 average score for the past 100ep -249.62933979098688
# Episode 1388 best score till now -0.10587543367834612 average score for the past 100ep -250.96391588184372
# Episode 1389 best score till now -0.10587543367834612 average score for the past 100ep -250.9342879609455
# Episode 1390 best score till now -0.10587543367834612 average score for the past 100ep -248.43586498853824
# Episode 1391 best score till now -0.10587543367834612 average score for the past 100ep -250.71368449992548
# Episode 1392 best score till now -0.10587543367834612 average score for the past 100ep -253.09397384113063
# Episode 1393 best score till now -0.10587543367834612 average score for the past 100ep -253.05221769173738
# Episode 1394 best score till now -0.10587543367834612 average score for the past 100ep -253.96789428485928
# Episode 1395 best score till now -0.10587543367834612 average score for the past 100ep -257.56621292424484
# Episode 1396 best score till now -0.10587543367834612 average score for the past 100ep -258.73507944986284
# Episode 1397 best score till now -0.10587543367834612 average score for the past 100ep -256.3323682089667
# Episode 1398 best score till now -0.10587543367834612 average score for the past 100ep -255.13615120618658
# Episode 1399 best score till now -0.10587543367834612 average score for the past 100ep -255.11835876485335
# Episode 1400 best score till now -0.10587543367834612 average score for the past 100ep -255.1169896237724
# Episode 1401 best score till now -0.10587543367834612 average score for the past 100ep -256.42748096584785
# Episode 1402 best score till now -0.10587543367834612 average score for the past 100ep -256.425187020654
# Episode 1403 best score till now -0.10587543367834612 average score for the past 100ep -255.20756316632855
# Episode 1404 best score till now -0.10587543367834612 average score for the past 100ep -250.4278524652265
# Episode 1405 best score till now -0.10587543367834612 average score for the past 100ep -254.8559483374009
# Episode 1406 best score till now -0.10587543367834612 average score for the past 100ep -254.82547205116214
# Episode 1407 best score till now -0.10587543367834612 average score for the past 100ep -252.43001350609856
# Episode 1408 best score till now -0.10587543367834612 average score for the past 100ep -253.59341624893645
# Episode 1409 best score till now -0.10587543367834612 average score for the past 100ep -252.47787643868537
# Episode 1410 best score till now -0.10587543367834612 average score for the past 100ep -253.0928230164732
# Episode 1411 best score till now -0.10587543367834612 average score for the past 100ep -251.84392898408962
# Episode 1412 best score till now -0.10587543367834612 average score for the past 100ep -255.4961449160165
# Episode 1413 best score till now -0.10587543367834612 average score for the past 100ep -255.57183455716523
# Episode 1414 best score till now -0.10587543367834612 average score for the past 100ep -255.7082728174056
# Episode 1415 best score till now -0.10587543367834612 average score for the past 100ep -259.3205258106895
# Episode 1416 best score till now -0.10587543367834612 average score for the past 100ep -256.96981933936075
# Episode 1417 best score till now -0.10587543367834612 average score for the past 100ep -256.9375391605527
# Episode 1418 best score till now -0.10587543367834612 average score for the past 100ep -255.68399598983476
# Episode 1419 best score till now -0.10587543367834612 average score for the past 100ep -256.86880802590366
# Episode 1420 best score till now -0.10587543367834612 average score for the past 100ep -260.3697174754114
# Episode 1421 best score till now -0.10587543367834612 average score for the past 100ep -259.16843461372827
# Episode 1422 best score till now -0.10587543367834612 average score for the past 100ep -262.6134783759445
# Episode 1423 best score till now -0.10587543367834612 average score for the past 100ep -261.31328770084025
# Episode 1424 best score till now -0.10587543367834612 average score for the past 100ep -261.31528214545165
# Episode 1425 best score till now -0.10587543367834612 average score for the past 100ep -260.1368103101646
# Episode 1426 best score till now -0.10587543367834612 average score for the past 100ep -260.1077414115054
# Episode 1427 best score till now -0.10587543367834612 average score for the past 100ep -255.3634240338623
# Episode 1428 best score till now -0.10587543367834612 average score for the past 100ep -254.1611394236126
# Episode 1429 best score till now -0.10587543367834612 average score for the past 100ep -255.29540186139687
# Episode 1430 best score till now -0.10587543367834612 average score for the past 100ep -254.11956005527932
# Episode 1431 best score till now -0.10587543367834612 average score for the past 100ep -252.98134032765455
# Episode 1432 best score till now -0.10587543367834612 average score for the past 100ep -255.49784300446424
# Episode 1433 best score till now -0.10587543367834612 average score for the past 100ep -255.48230994187162
# Episode 1434 best score till now -0.10587543367834612 average score for the past 100ep -257.79079653487844
# Episode 1435 best score till now -0.10587543367834612 average score for the past 100ep -256.7097717126843
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-e9e8d645dbe9> in <module>()
#      15     e1 = Experience(observation,next_state,action,reward,done)
#      16     agent.store(e1)
# ---> 17     agent.learn()
#      18     score+=reward
#      19     observation = next_state
#
# <ipython-input-31-0c735ec64b09> in learn(self)
#      65     if self.memory.is_available(self.batch_size):
#      66       state,action,next_state,reward,done = self.memory.sample(self.batch_size)
# ---> 67       target_action = self.targetactor.forward(next_state)
#      68       target_action += torch.clamp(torch.tensor(np.random.normal(scale=0.2)),-0.5,0.5)
#      69       target_action = torch.clamp(target_action,self.min_action[0],self.max_action[0])
#
# <ipython-input-6-2bdd7ead69cd> in forward(self, state)
#      15     out = self.fc2(out)
#      16     out = F.relu(out)
# ---> 17     out = torch.tanh(self.fc3(out))
#      18     return out
#      19   def save_checkpoints(self):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# KeyboardInterrupt:

# %%
re = np.array([1,2,3,4,5])
np.mean(re[-100:])
# Out:
# 3.0

# %%
# !sudo apt-get install build-essential python-dev swig python-pygame
# !pip install box2d-py
